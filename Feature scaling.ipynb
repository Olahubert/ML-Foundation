# %%
import seaborn as sns
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

# %%
#To see all the dataset available in seaborn
sns.get_dataset_names()
#To extract the data we use  = smp.load_dataset("
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
Tip=sns.load_dataset("tips")

# %%
Tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Standardization: The data transformation scales a particular column to a mean of 0 and a standard deviation of 1. The original formular for standardisation is
# #Standardized_value = (Original_value - Mean) / Standard_deviation

# %%
Total_b=Tip['total_bill']

# %%
#Reshape
Total_b.shape
# Out:
# (244,)

# %%
Total_b.values.reshape(-1,1)
# Out:
# array([[16.99],
#        [10.34],
#        [21.01],
#        [23.68],
#        [24.59],
#        [25.29],
#        [ 8.77],
#        [26.88],
#        [15.04],
#        [14.78],
#        [10.27],
#        [35.26],
#        [15.42],
#        [18.43],
#        [14.83],
#        [21.58],
#        [10.33],
#        [16.29],
#        [16.97],
#        [20.65],
#        [17.92],
#        [20.29],
#        [15.77],
#        [39.42],
#        [19.82],
#        [17.81],
#        [13.37],
#        [12.69],
#        [21.7 ],
#        [19.65],
#        [ 9.55],
#        [18.35],
#        [15.06],
#        [20.69],
#        [17.78],
#        [24.06],
#        [16.31],
#        [16.93],
#        [18.69],
#        [31.27],
#        [16.04],
#        [17.46],
#        [13.94],
#        [ 9.68],
#        [30.4 ],
#        [18.29],
#        [22.23],
#        [32.4 ],
#        [28.55],
#        [18.04],
#        [12.54],
#        [10.29],
#        [34.81],
#        [ 9.94],
#        [25.56],
# ...

# %%
X=Total_b.values.reshape(-1,1)

# %%
#To standardize your dataset during machine learning, you have to import the StandardScaler class like this below
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
Tip['New_total_bill'] = scaler.fit_transform(X)

# %%
Tip['New_total_bill']
# Out:
# 0     -0.314711
# 1     -1.063235
# 2      0.137780
# 3      0.438315
# 4      0.540745
#          ...
# 239    1.040511
# 240    0.832275
# 241    0.324630
# 242   -0.221287
# 243   -0.113229
# Name: New_total_bill, Length: 244, dtype: float64

# %%
Tip
# Out:
#      total_bill   tip     sex smoker   day    time  size  New_total_bill  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2       -0.314711
# 1         10.34  1.66    Male     No   Sun  Dinner     3       -1.063235
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0.137780
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0.438315
# 4         24.59  3.61  Female     No   Sun  Dinner     4        0.540745
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        1.040511
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        0.832275
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0.324630
# 242       17.82  1.75    Male     No   Sat  Dinner     2       -0.221287
# 243       18.78  3.00  Female     No  Thur  Dinner     2       -0.113229
#
#          tip2  size2
# 0    0.001111    0.2
# 1    0.073333    0.4
# 2    0.277778    0.4
# ...

# %%
#Delete unwanted column
Tip = Tip.drop('New_totaX)l_bill', axis=1)

# %%
#for two columns

# %%
X = Tip[['tip','size']].values

# %% [markdown]
# # Normalization: it is a data transformation that has to do with the minimum and the maximum value in your dataset. It ranges from 0-1 or sometimes it can be from -1 to 1.The formular for normalisation is
# #Normalized_value = (Original_value - Min_value) / (Max_value - Min_value)

# %%
Tip2=sns.load_dataset("tips")

# %%
Tip2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#To normalize your dataset during machine learning, you have to import the MinMaxScaler class like this below
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
Tip_size=Tip2[['tip','size']]

# %%
Tip2[["tip2", "size2"]] = scaler.fit_transform(Tip_size)

# %%
Tip2
# Out:
#      total_bill   tip     sex smoker   day    time  size      tip2  size2
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.001111    0.2
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.073333    0.4
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.277778    0.4
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.256667    0.2
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.290000    0.6
# ..          ...   ...     ...    ...   ...     ...   ...       ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.546667    0.4
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.111111    0.2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.111111    0.2
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.083333    0.2
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.222222    0.2
#
# [244 rows x 9 columns]
