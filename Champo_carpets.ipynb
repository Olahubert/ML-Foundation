# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_excel('Champ_Carpets2.xlsx')

# %%
df
# Out:
#        OrderType OrderCategory CustomerCode CountryName CustomerOrderNo  \
# 0      Area Wise         Order          H-1         USA         1873354
# 1      Area Wise         Order          H-1         USA         1873354
# 2      Area Wise         Order          H-1         USA         1873354
# 3      Area Wise         Order          H-1         USA         1918436
# 4      Area Wise         Order          H-1         USA         1873354
# ...          ...           ...          ...         ...             ...
# 18950  Area Wise        Sample          T-2       ITALY          S 1278
# 18951  Area Wise        Sample          T-2       ITALY          S 1278
# 18952  Area Wise        Sample          T-2       ITALY          S 1278
# 18953  Area Wise        Sample          A-9         USA          S 1280
# 18954  Area Wise        Sample           CC       INDIA          S 1281
#
#       Custorderdate UnitName  QtyRequired  TotalArea  Amount    ITEM_NAME  \
# ...

# %%
df.isnull().sum()
# Out:
# OrderType          0
# OrderCategory      0
# CustomerCode       0
# CountryName        0
# CustomerOrderNo    9
# Custorderdate      0
# UnitName           0
# QtyRequired        0
# TotalArea          0
# Amount             0
# ITEM_NAME          0
# QualityName        0
# DesignName         0
# ColorName          0
# ShapeName          0
# AreaFt             0
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#        OrderType OrderCategory CustomerCode CountryName CustomerOrderNo  \
# 0      Area Wise         Order          H-1         USA         1873354
# 1      Area Wise         Order          H-1         USA         1873354
# 2      Area Wise         Order          H-1         USA         1873354
# 3      Area Wise         Order          H-1         USA         1918436
# 4      Area Wise         Order          H-1         USA         1873354
# ...          ...           ...          ...         ...             ...
# 18950  Area Wise        Sample          T-2       ITALY          S 1278
# 18951  Area Wise        Sample          T-2       ITALY          S 1278
# 18952  Area Wise        Sample          T-2       ITALY          S 1278
# 18953  Area Wise        Sample          A-9         USA          S 1280
# 18954  Area Wise        Sample           CC       INDIA          S 1281
#
#       Custorderdate UnitName  QtyRequired  TotalArea  Amount    ITEM_NAME  \
# ...

# %%
numerical_cols = ['QtyRequired', 'TotalArea', 'Amount']
for col in numerical_cols:
    print(f"Descriptive Statistics for {col}:")
    print(df[col].describe())
# Out:
# Descriptive Statistics for QtyRequired:
# count    18946.000000
# mean        31.422781
# std        191.494618
# min          1.000000
# 25%          1.000000
# 50%          4.000000
# 75%         13.000000
# max       6400.000000
# Name: QtyRequired, dtype: float64
# Descriptive Statistics for TotalArea:
# count    18946.000000
# mean        36.158776
# std         45.178080
# min          0.040000
# 25%          4.000000
# 50%         15.000000
# 75%         54.000000
# max       1024.000000
# Name: TotalArea, dtype: float64
# Descriptive Statistics for Amount:
# count     18946.000000
# mean       1658.042390
# std       14058.238359
# min           0.000000
# 25%           0.000000
# 50%         200.625000
# 75%         975.000000
# max      599719.680000
# Name: Amount, dtype: float64

# %%
categorical_cols = ['OrderType', 'OrderCategory', 'CustomerCode', 'CountryName', 'CustomerOrderNo', 'Custorderdate', 'UnitName', 'QualityName', 'DesignName', 'ColorName', 'ShapeName']
for col in categorical_cols:
    print(f"Unique Values for {col}:")
    print(df[col].unique())
# Out:
# Unique Values for OrderType:
# ['Area Wise' 'Pc Wise']
# Unique Values for OrderCategory:
# ['Order' 'Sample']
# Unique Values for CustomerCode:
# ['H-1' 'C-1' 'CC' 'M-1' 'E-2' 'B-3' 'G-1' 'M-2' 'P-5' 'T-2' 'I-2' 'RC'
#  'T-6' 'JL' 'S-2' 'P-4' 'DR' 'PC' 'A-9' 'PD' 'K-2' 'T-5' 'T-4' 'A-6' 'B-2'
#  'G-4' 'B-4' 'C-2' 'L-2' 'F-1' 'F-2' 'H-2' 'C-3' 'R-4' 'V-1' 'L-5' 'TGT'
#  'A-11' 'N-1' 'CTS' 'S-3' 'L-4' 'L-3' 'K-3' 'F-6' 'T-9']
# Unique Values for CountryName:
# ['USA' 'INDIA' 'CANADA' 'SOUTH AFRICA' 'ITALY' 'ROMANIA' 'AUSTRALIA' 'UK'
#  'LEBANON' 'BELGIUM' 'BRAZIL' 'CHINA' 'ISRAEL' 'POLAND' 'UAE']
# Unique Values for CustomerOrderNo:
# [1873354 1918436 2149526 ... 'S 1272' 'S 1280' 'S 1281']
# Unique Values for Custorderdate:
# <DatetimeArray>
# ['2017-01-16 00:00:00', '2017-02-01 00:00:00', '2017-07-12 00:00:00',
#  '2017-09-04 00:00:00', '2017-05-12 00:00:00', '2017-05-25 00:00:00',
#  '2017-02-27 00:00:00', '2017-10-31 00:00:00', '2018-10-08 00:00:00',
#  '2019-01-18 00:00:00',
# ...

# %%
plt.figure(figsize=(17,6))
sns.countplot(x='CountryName', data=df)
plt.title('Distribution of Orders by Country')
plt.savefig('Champ_Carpets5.png')
plt.show()

# %%
sns.scatterplot(data=df, x='TotalArea', y='Amount')
plt.title('Order Amount vs Total Area')
plt.savefig('Champ_Carpets3.png')
plt.show()

# %%
df['Custorderdate'] = pd.to_datetime(df['Custorderdate'])
df['Year'] = df['Custorderdate'].dt.year
sns.lineplot(data=df, x='Year', y='QtyRequired')
plt.title('Quantity Required Over Time')
plt.savefig('Champ_Carpets4.png')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11080\452238290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Custorderdate'] = pd.to_datetime(df['Custorderdate'])
# C:\Users\USER\AppData\Local\Temp\ipykernel_11080\452238290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Custorderdate'].dt.year
